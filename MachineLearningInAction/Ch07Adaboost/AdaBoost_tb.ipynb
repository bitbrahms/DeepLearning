# %%
import adaboost
import numpy as np 
from imp import reload
reload(adaboost)
import math

# %%
dataMat, classLabel = adaboost.loadSimpData()

# %%
D=np.mat(np.ones((5,1))/5)

# %%
reload(adaboost)
# Out:
# <module 'adaboost' from 'D:\\CPU_Manny\\workspace\\DeepLearning\\MachineLearningInAction\\Ch07A daboost\\adaboost.py'>

# %%
adaboost.bulidStump(dataMat, classLabel,D)
# Out:
# ({'dim': 0, 'ineq': 'lt', 'thread': 1.3}, 0.20000000000000001, array([[-1.],
#         [ 1.],
#         [-1.],
#         [-1.],
#         [ 1.]]))

# %%
adaboost.adaBoostTrain(dataMat, classLabel)
# Out:
# total error:  0.2
#
# total error:  0.2
#
# total error:  0.0
# [{'alpha': 0.6931471805599453, 'dim': 0, 'ineq': 'lt', 'thread': 1.3},
#  {'alpha': 0.9729550745276565, 'dim': 1, 'ineq': 'lt', 'thread': 1.0},
#  {'alpha': 0.8958797346140273,
#   'dim': 0,
#   'ineq': 'lt',
#   'thread': 0.90000000000000002}]

# %%
classifyArray = adaboost.adaBoostTrain(dataMat,classLabel,9)
# Out:
# classEst:  [[-1.  1. -1. -1.  1.]]
# total error:  0.2
#
# classEst:  [[ 1.  1. -1. -1. -1.]]
# total error:  0.2
#
# classEst:  [[ 1.  1.  1.  1.  1.]]
# total error:  0.0

# %%
classifyArray
# Out:
# [{'alpha': 0.6931471805599453, 'dim': 0, 'ineq': 'lt', 'thread': 1.3},
#  {'alpha': 0.9729550745276565, 'dim': 1, 'ineq': 'lt', 'thread': 1.0},
#  {'alpha': 0.8958797346140273,
#   'dim': 0,
#   'ineq': 'lt',
#   'thread': 0.90000000000000002}]

# %%
a
# Out:
# [{'alpha': nan},
#  {'alpha': nan},
#  {'alpha': nan},
#  {'alpha': nan},
#  {'alpha': nan},
#  {'alpha': nan},
#  {'alpha': nan},
#  {'alpha': nan},
#  {'alpha': nan},
#  {'alpha': nan}]

# %%
int(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-502-c8db2292b237> in <module>()
# ----> 1 int(a)
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'list'

# %%
a=np.mat([1,2,3])
b=np.mat([3,2,1])

# %%
c=a*b.transpose()

# %%
c[0,0]

# %%
float(c)

# %%
weakclass=adaboost.adaBoostTrain(dataMat,classLabel,10)
# Out:
# total error:  0.404682274247
#
# total error:  0.404682274247
#
# total error:  0.404682274247
#
# total error:  0.404682274247
#
# total error:  0.404682274247
#
# total error:  0.404682274247
#
# total error:  0.404682274247
#
# total error:  0.404682274247
#
# total error:  0.404682274247
#
# total error:  0.404682274247

# %%
adaboost.adaClassify([0,0],weakclass)

# %%
adaboost.adaClassify([[0,0],[5,5]],weakclass)

# %%
dataMat,classLabel = adaboost.loadDataSet('../Ch05/horseColicTraining.txt')

# %%
weakclass=adaboost.adaBoostTrain(dataMat,classLabel,10)
# Out:
# total error:  0.404682274247
#
# total error:  0.404682274247
#
# total error:  0.404682274247
#
# total error:  0.404682274247
#
# total error:  0.404682274247
#
# total error:  0.404682274247
#
# total error:  0.404682274247
#
# total error:  0.404682274247
#
# total error:  0.404682274247
#
# total error:  0.404682274247

# %%
testArr,testLabel = adaboost.loadDataSet('../Ch05/horseColicTest.txt')

# %%
a = adaboost.adaClassify(testArr,weakclass)
# Out:
# [[ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
#  [ 0.1929965]
# ...

# %%
errArr = np.mat(np.ones((67,1)))

# %%
errArr[a != np.mat(testLabel).transpose()].sum()
# Out:
# 20.0
