# %%
import svm
from imp import reload
import numpy as np
reload(svm)
# Out:
# <module 'svm' from 'D:\\CPU_Manny\\workspace\\DeepLearning\\MachineLearningInAction\\Ch06\\svm.py'>

# %%
dataMatrix,labelMatrix=svm.loadDataSet('testSet.txt')

# %%
b,alphas= svm.simplifiedSmo(dataMatrix,labelMatrix,0.6, 0.001, 40)
# Out:
# L==H
# iter: 0 i: 1,pairs changed 1
# iter: 0 i: 2,pairs changed 2
# L==H
# L==H
# L==H
# iter: 0 i: 8,pairs changed 3
# j not moving enough
# L==H
# L==H
# L==H
# L==H
# L==H
# j not moving enough
# iter: 0 i: 54,pairs changed 4
# iter: 0 i: 55,pairs changed 5
# j not moving enough
# L==H
# L==H
# j not moving enough
# iter num is: 0
# j not moving enough
# iter: 0 i: 2,pairs changed 1
# j not moving enough
# j not moving enough
# L==H
# j not moving enough
# j not moving enough
# L==H
# iter: 0 i: 34,pairs changed 2
# j not moving enough
# L==H
# j not moving enough
# iter: 0 i: 53,pairs changed 3
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# iter: 0 i: 83,pairs changed 4
# j not moving enough
# L==H
# iter: 0 i: 97,pairs changed 5
# iter num is: 0
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# L==H
# j not moving enough
# iter: 0 i: 29,pairs changed 1
# j not moving enough
# ...

# %%
dataMatrix=np.mat(dataMatrix)

# %%
type(dataMatrix)
# Out:
# numpy.matrixlib.defmatrix.matrix

# %%
a=np.mat(dataMatrix[1,:]).transpose

# %%
type(dataMatrix.transpose())
# Out:
# numpy.matrixlib.defmatrix.matrix

# %%
b
# Out:
# matrix([[-3.80010732]])

# %%
alphas[alphas>0]
# Out:
# matrix([[ 0.10075603,  0.25743179,  0.0179386 ,  0.34024922]])
