# %%
import svm
from imp import reload
import numpy as np
reload(svm)
# Out:
# <module 'svm' from 'D:\\CPU_Manny\\workspace\\DeepLearning\\MachineLearningInAction\\Ch06\\svm.py'>

# %%
dataMatrix,labelMatrix=svm.loadDataSet('testSet.txt')

# %%
b,alphas= svm.simplifiedSmo(dataMatrix,labelMatrix,0.6, 0.001, 40)
# Out:
# L==H
# L==H
# L==H
# L==H
# iter: 0 i: 4,pairs changed 1
# iter: 0 i: 5,pairs changed 2
# L==H
# L==H
# j not moving enough
# L==H
# iter: 0 i: 13,pairs changed 3
# iter: 0 i: 17,pairs changed 4
# j not moving enough
# j not moving enough
# L==H
# j not moving enough
# j not moving enough
# L==H
# j not moving enough
# j not moving enough
# L==H
# L==H
# L==H
# iter: 0 i: 54,pairs changed 5
# L==H
# j not moving enough
# j not moving enough
# j not moving enough
# L==H
# j not moving enough
# L==H
# L==H
# j not moving enough
# j not moving enough
# j not moving enough
# iter num is: 0
# j not moving enough
# L==H
# j not moving enough
# j not moving enough
# iter: 0 i: 7,pairs changed 1
# L==H
# L==H
# L==H
# j not moving enough
# iter: 0 i: 17,pairs changed 2
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# iter num is: 0
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# ...

# %%
dataMatrix=np.mat(dataMatrix)

# %%
type(dataMatrix)
# Out:
# numpy.matrixlib.defmatrix.matrix

# %%
a=np.mat(dataMatrix[1,:]).transpose

# %%
type(dataMatrix.transpose())
# Out:
# numpy.matrixlib.defmatrix.matrix

# %%
b
# Out:
# matrix([[-3.79018279]])

# %%
alphas[alphas>0]
# Out:
# matrix([[ 0.16503477,  0.11496949,  0.08488298,  0.36488724]])

# %%
data = np.mat([[1,0,1],[0,0,1]])

# %%
np.nonzero(data)[0]
# Out:
# array([0, 0, 1], dtype=int32)

# %%
np.nonzero(data.getA())[0]
# Out:
# array([0, 0, 1], dtype=int32)

# %%
import svm

# %%
dataArr,labelArr = svm.loadDataSet('testSet.txt')

# %%
b,alphas = svm.smoP(dataArr, labelArr, 0.6, 0.001, 40)
# Out:
# L==H
# L==H
# L==H
# L==H
# L==H
# j not moving enough
# fullSet,iter: 0 i: 99, pairs changed 5
# iternation num :1
# nonBoundIS, iter :1 i: 8,pairs changed 1
# nonBoundIS, iter :1 i: 10,pairs changed 2
# j not moving enough
# nonBoundIS, iter :1 i: 52,pairs changed 2
# nonBoundIS, iter :1 i: 54,pairs changed 3
# nonBoundIS, iter :1 i: 55,pairs changed 4
# iternation num :2
# j not moving enough
# nonBoundIS, iter :2 i: 8,pairs changed 0
# j not moving enough
# nonBoundIS, iter :2 i: 17,pairs changed 0
# j not moving enough
# nonBoundIS, iter :2 i: 29,pairs changed 0
# nonBoundIS, iter :2 i: 52,pairs changed 0
# j not moving enough
# nonBoundIS, iter :2 i: 54,pairs changed 0
# nonBoundIS, iter :2 i: 55,pairs changed 0
# iternation num :3
# j not moving enough
# j not moving enough
# j not moving enough
# j not moving enough
# fullSet,iter: 3 i: 99, pairs changed 0
# iternation num :4

# %%
a = np.mat([1,2,3,4,5])

# %%
a
# Out:
# matrix([[1, 2, 3, 4, 5]])

# %%
np.nonzero((a>2) * (a<6))[0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-fecacbb1cdc6> in <module>()
# ----> 1 np.nonzero((a>2) * (a<6))[0]
#
# C:\workspace\Anaconda3\lib\site-packages\numpy\matrixlib\defmatrix.py in __mul__(self, other)
#     341         if isinstance(other, (N.ndarray, list, tuple)) :
#     342             # This promotes 1-D vectors to row vectors
# --> 343             return N.dot(self, asmatrix(other))
#     344         if isscalar(other) or not hasattr(other, '__rmul__') :
#     345             return N.dot(self, other)
#
# ValueError: shapes (1,5) and (1,5) not aligned: 5 (dim 1) != 1 (dim 0)

# %%
ws = svm.calcWs(alphas, dataArr, labelArr)

# %%
ws
# Out:
# array([[ 0.79217255],
#        [-0.25433037]])

# %%
dataMatrix = np.mat(dataArr)

# %%
dataMatrix[2]*ws + b
# Out:
# matrix([[ 2.67362096]])

# %%
import svm
from imp import reload
import numpy as np
reload(svm)
# Out:
# <module 'svm' from 'D:\\CPU_Manny\\workspace\\DeepLearning\\MachineLearningInAction\\Ch06\\svm.py'>

# %%
svm.testRbf()
# Out:
# L==H
# j not moving enough
# j not moving enough
# j not moving enough
# L==H
# L==H
# L==H
# j not moving enough
# L==H
# j not moving enough
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# L==H
# fullSet,iter: 0 i: 99, pairs changed 28
# iternation num :1
# j not moving enough
# nonBoundIS, iter :1 i: 0,pairs changed 0
# j not moving enough
# nonBoundIS, iter :1 i: 1,pairs changed 0
# j not moving enough
# nonBoundIS, iter :1 i: 3,pairs changed 0
# j not moving enough
# nonBoundIS, iter :1 i: 10,pairs changed 0
# j not moving enough
# nonBoundIS, iter :1 i: 11,pairs changed 0
# j not moving enough
# nonBoundIS, iter :1 i: 13,pairs changed 0
# j not moving enough
# nonBoundIS, iter :1 i: 14,pairs changed 0
# j not moving enough
# nonBoundIS, iter :1 i: 15,pairs changed 0
# j not moving enough
# nonBoundIS, iter :1 i: 16,pairs changed 0
# j not moving enough
# nonBoundIS, iter :1 i: 17,pairs changed 0
# j not moving enough
# nonBoundIS, iter :1 i: 18,pairs changed 0
# ...

# %%
from math import exp

# %%
exp
# Out:
# <function math.exp>

# %%
from math import sign
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-114-e15e979a4dca> in <module>()
# ----> 1 from math import sign
#
# ImportError: cannot import name 'sign'
