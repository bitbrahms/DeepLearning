# %% [markdown]
# # EM算法

# %% [markdown]
# ### Jensen不等式

# %% [markdown]
# ![jensen%E4%B8%8D%E7%AD%89%E5%BC%8F_1.png](attachment:jensen%E4%B8%8D%E7%AD%89%E5%BC%8F_1.png)

# %% [markdown]
# ![jensen%E4%B8%8D%E7%AD%89%E5%BC%8F.png](attachment:jensen%E4%B8%8D%E7%AD%89%E5%BC%8F.png)
